# %%
import re
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.datasets import imdb

from keras.utils.np_utils import to_categorical

import warnings
warnings.filterwarnings('ignore')
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
max_features = 1000
maxlen = 80  # cut texts after this number of words (among top max_features most common words)
batch_size = 32

print('Loading data...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')

print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Loading data...
# 25000 train sequences
# 25000 test sequences
# Pad sequences (samples x time)
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)

# %%
INDEX_FROM=3   # word index offset

word_to_id = imdb.get_word_index()
word_to_id = {k:(v+INDEX_FROM) for k,v in word_to_id.items()}
word_to_id["<PAD>"] = 0
word_to_id["<START>"] = 1
word_to_id["<UNK>"] = 2

id_to_word = {value:key for key,value in word_to_id.items()}
print(' '.join(id_to_word[id] for id in x_train[15] ))
# Out:
# will have this sorry <UNK> for a movie i really got a laugh out of the dr evil like <UNK> <UNK> <UNK> the plot was <UNK> between <UNK> and non <UNK> how many <UNK> are <UNK> to make a <UNK> <UNK> <UNK> <UNK> on a car <UNK> <UNK> 4 but didn't they become <UNK> through <UNK> <UNK> this was written for <UNK> <UNK> it plays like a video game i did enjoy the <UNK> <UNK> <UNK> in the <UNK> though

# %%
print('Build model...')
model = Sequential()
model.add(Embedding(max_features, 8))
model.add(LSTM(16, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, None, 8)           8000
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 16)                1600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 9,617
# Trainable params: 9,617
# Non-trainable params: 0
# _________________________________________________________________

# %%
# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Write the training input and output, batch size, and testing input and output

model.fit(x_train, y_train, 
          batch_size=batch_size, 
          epochs=1, 
          validation_data=(x_test, y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/1
# 25000/25000 [==============================] - 25s 1ms/step - loss: 0.5551 - acc: 0.7104 - val_loss: 0.4618 - val_acc: 0.7892

# %%
score, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 25000/25000 [==============================] - 3s 134us/step
# Test score: 0.4618188527679443
# Test accuracy: 0.78916

# %%
prediction = model.predict(x_test[20:21])
#print(x_test[13:14])
print('Prediction value:',prediction[0])
print('Test Label:',y_test[12:13])
# Out:
# Prediction value: [0.9094635]
# Test Label: [0]

# %%
data = pd.read_csv(r'C:\Users\Hrishikesh Nikam\Desktop\internship\dataset\train.csv',encoding='latin-1')
# Keeping only the neccessary columns

# %%
data.head(5772)
# Out:
#       ItemID  Sentiment                                      SentimentText
# 0          1          0                       is so sad for my APL frie...
# 1          2          0                     I missed the New Moon trail...
# 2          3          1                            omg its already 7:30 :O
# 3          4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4          5          0           i think mi bf is cheating on me!!!   ...
# 5          6          0                  or i just worry too much?
# 6          7          1                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7          8          0         Sunny Again        Work Tomorrow  :-|  ...
# 8          9          1        handed in my uniform today . i miss you ...
# 9         10          1           hmmmm.... i wonder how she my number @-)
# 10        11          0                      I must think about positive..
# 11        12          1        thanks to all the haters up in my face a...
# 12        13          0                     this weekend has sucked so far
# 13        14          0             jb isnt showing in australia any more!
# 14        15          0                               ok thats it you win.
# 15        16          0      &lt;-------- This is the way i feel right ...
# 16        17          0      awhhe man.... I'm completely useless rt no...
# 17        18          1      Feeling strangely fine. Now I'm gonna go l...
# 18        19          0       HUGE roll of thunder just now...SO scary!!!!
# 19        20          0      I just cut my beard off. It's only been gr...
# 20        21          0                               Very sad about Iran.
# 21        22          0                                      wompppp wompp
# 22        23          1      You're the only one who can see this cause...
# 23        24          0     &lt;---Sad level is 3. I was writing a mass...
# 24        25          0     ...  Headed to Hospitol : Had to pull out o...
# 25        26          0     BoRinG   ): whats wrong with him??     Plea...
# 26        27          0     can't be bothered. i wish i could spend the...
# 27        28          0     Feeeling like shit right now. I really want...
# 28        29          1              goodbye exams, HELLO ALCOHOL TONIGHT
# 29        30          0     I didn't realize it was THAT deep. Geez giv...
# ...      ...        ...                                                ...
# 5742    5745          0  #haveyouever been in a long distance relations...
# 5743    5746          0  #haveyouever been put in a full nelson on your...
# 5744    5747          0  #haveyouever been unable to do something even ...
# 5745    5748          1  #haveyouever broken a window or sth like me ??...
# 5746    5749          0  #haveyouever cooked for your boyfriend and lat...
# 5747    5750          0  #haveyouever drive in the rain?  http://bit.ly...
# 5748    5751          0  #haveyouever dropped ur iPod/iPhone and freake...
# 5749    5752          1  #haveyouever dunked pizza in ranch? ha thats t...
# 5750    5753          0  #haveyouever eatin a candybar in bed to wake u...
# 5751    5754          0  #haveyouever ended a good relationship because...
# 5752    5755          1  #haveyouever Fall off of bed because of a drea...
# 5753    5756          0  #haveyouever gotten your heart broken?  worst ...
# 5754    5757          1  #Haveyouever kissed a band member? I want to s...
# 5755    5758          1  #haveyouever listened to Lights? she's awesome...
# 5756    5759          0              #haveyouever lost a twitter follower
# 5757    5760          0  #haveyouever missed someone so much it made yo...
# 5758    5761          0  #haveyouever murdered someone cause God told y...
# 5759    5762          0   ngÃ y nÃ y mÃ² vá»¥ application facebook mÃ  ...
# 5760    5763          0                    Ngidem cinnamon roll+hot choco.
# 5761    5764          1                         Nice and sunny. Love ittt.
# 5762    5765          1             nice day outside. Laying down sleepin.
# 5763    5766          1   nice day with my friend  loove you tata   wha...
# 5764    5767          0              night going to bed early cuz I'm sick
# 5765    5768          1   night my loves p.s hope everyone effected by ...
# 5766    5769          0   nightmares about blowing up in a van with my ...
# 5767    5770          1                                           nighty..
# 5768    5771          0   no air and its likke 80 outside  and im soooo...
# 5769    5772          0           no cosmic bowling *nearly begins to cry*
# 5770    5773          0   No farmer's mks! Rt @TOfoodie: Itâs officia...
# 5771    5774          0   no fireworks and no electrical parade this su...
#
# [5772 rows x 3 columns]

# %%
data['SentimentText'] = data['SentimentText'].apply(lambda x: x.lower())
data['SentimentText'] = data['SentimentText'].apply((lambda x: re.sub('[^a-zA-z0-9\s]','',x)))


max_fatures = 2000
tokenizer = Tokenizer(nb_words=max_fatures, split=' ')
tokenizer.fit_on_texts(data['SentimentText'].values)
X = tokenizer.texts_to_sequences(data['SentimentText'].values)
X = pad_sequences(X)

# %%
Y = pd.get_dummies(data['Sentiment']).values
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.33, random_state = 42)
print('Shape of training samples:',X_train.shape,Y_train.shape)
print('Shape of testing samples:',X_test.shape,Y_test.shape)
# Out:
# Shape of training samples: (66992, 84) (66992, 2)
# Shape of testing samples: (32997, 84) (32997, 2)

# %%
model = Sequential()
model.add(Embedding(max_fatures, 128 ,input_length = X.shape[1], dropout=0.2))
model.add(LSTM(128))
model.add(Dense(2, activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 84, 128)           256000
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 387,842
# Trainable params: 387,842
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
batch_size = 32
model.fit(X_train, Y_train, epochs = 5, batch_size=batch_size, verbose = 2)
# Out:
# Epoch 1/5
#  - 119s - loss: 0.4798 - acc: 0.7664
# Epoch 2/5
#  - 121s - loss: 0.4530 - acc: 0.7822
# Epoch 3/5
#  - 119s - loss: 0.4337 - acc: 0.7945
# Epoch 4/5
#  - 122s - loss: 0.4140 - acc: 0.8060
# Epoch 5/5
#  - 119s - loss: 0.3917 - acc: 0.8167

# %%
score,acc = model.evaluate(X_test, Y_test, verbose = 2, batch_size = batch_size)
print("Score: %.2f" % (score))
print("Accuracy: %.2f" % (acc))
# Out:
# Score: 0.51
# Accuracy: 0.76

# %%
text = 'i love you'
tester = np.array([text])
tester = pd.DataFrame(tester)
tester.columns = ['text']

tester['text'] = tester['text'].apply(lambda x: x.lower())
tester['text'] = tester['text'].apply((lambda x: re.sub('[^a-zA-z0-9\s]','',x)))

max_fatures = 2000
test = tokenizer.texts_to_sequences(tester['text'].values)
test = pad_sequences(test)

if X.shape[1]>test.shape[1]:
    test = np.pad(test[0], (X.shape[1]-test.shape[1],0), 'constant')
    
test = np.array([test])

prediction = model.predict(test)
print('Prediction value:',prediction[0])
# Out:
# Prediction value: [0.06077963 0.93922037]
